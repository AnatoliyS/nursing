# %%
import ioutils as io;
import matplotlib;
import matplotlib.pyplot as plt

# %%
# Run the above function and store its results in a variable.   
full_file_paths = io.get_filepaths("./data/Labelled/sensors")
full_file_paths[2]
# Out:
# './data/Labelled/sensors/N100_20140212_084613-172252.csv'

# %%
from record import NurseSensorsRecord;
x = NurseSensorsRecord(full_file_paths[0])
x.frame

# %%
# %matplotlib inline

# %%
plt.plot(x.frame.iloc[:,0], x.frame.iloc[:,3])
plt.plot(x.frame.iloc[:,0], x.frame.iloc[:,1])
plt.plot(x.frame.iloc[:,0], x.frame.iloc[:,2])
plt.show()

plt.figure()
plt.plot(x.frame.iloc[:,0], x.frame.iloc[:,4])
plt.plot(x.frame.iloc[:,0], x.frame.iloc[:,5])
plt.plot(x.frame.iloc[:,0], x.frame.iloc[:,6])
plt.show()
