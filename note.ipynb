# %%
print('hi')
# Out:
# hi

# %%
import ioutils as io;

# %%
# Run the above function and store its results in a variable.   
full_file_paths = io.get_filepaths("./data/Labelled/sensors")

# %%
full_file_paths[2]
# Out:
# './data/Labelled/sensors/N201_20140214_084543-105911.csv'

# %%
from record import NurseRecord;

# %%
x = NurseRecord(full_file_paths[0])
# Out:
# Nurse record created

# %%
x.frame
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>time</th>
#       <th>chest_x</th>
#       <th>chest_y</th>
#       <th>chest_z</th>
#       <th>waist_x</th>
#       <th>waist_y</th>
#       <th>waist_z</th>
#       <th>right_x</th>
#       <th>right_y</th>
#       <th>right_z</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.050</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>0.00000</td>
#       <td>-0.078125</td>
#       <td>0.15625</td>
#       <td>1.01563</td>
#       <td>0.34375</td>
#       <td>0.87500</td>
#       <td>-0.34375</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>0.151</td>
#       <td>0.01714</td>
#       <td>-0.03015</td>
#       <td>-0.98618</td>
#       <td>-0.078125</td>
#       <td>0.15625</td>
#       <td>1.03125</td>
#       <td>0.34375</td>
#       <td>0.87500</td>
#       <td>-0.34375</td>
#     </tr>
#     <tr>
# ...

# %%
# %matplotlib inline

# %%
plot(x.frame.iloc[:,0], x.frame.iloc[:,3])
plot(x.frame.iloc[:,0], x.frame.iloc[:,1])
plot(x.frame.iloc[:,0], x.frame.iloc[:,2])
show()

# %%
figure()

# %%
plot(x.frame.iloc[:,0], x.frame.iloc[:,4])
plot(x.frame.iloc[:,0], x.frame.iloc[:,5])
plot(x.frame.iloc[:,0], x.frame.iloc[:,6])
show()
