# %%
import pandas as pd

pd.read_csv('data/Labelled/features.csv', header=0)
# Out:
# <div>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>chest_norm_mean</th>
#       <th>chest_norm_std</th>
#       <th>chest_y_mean</th>
#       <th>chest_y_std</th>
#       <th>chest_z_mean</th>
#       <th>chest_z_std</th>
#       <th>record_length</th>
#       <th>right_norm_mean</th>
#       <th>right_norm_std</th>
#       <th>right_x_mean</th>
#       <th>...</th>
#       <th>right_z_mean</th>
#       <th>right_z_std</th>
#       <th>waist_norm_mean</th>
#       <th>waist_norm_std</th>
#       <th>waist_x_mean</th>
#       <th>waist_x_std</th>
#       <th>waist_y_mean</th>
#       <th>waist_y_std</th>
#       <th>waist_z_mean</th>
#       <th>waist_z_std</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>0.866376</td>
#       <td>0.368933</td>
#       <td>-0.014622</td>
#       <td>0.184635</td>
#       <td>-0.850883</td>
#       <td>0.353407</td>
#       <td>1998</td>
# ...
