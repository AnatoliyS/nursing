# %%
import pandas as pd

pd.read_csv('data/Labelled/features.csv', header=0)
# Out:
#      Unnamed: 0  chest_norm_mean  chest_norm_std  chest_y_mean  chest_y_std  \
# 0             0         0.963413        0.178709      0.006285     0.173801
# 1             1         1.008257        0.086637     -0.127928     0.102357
# 2             2         0.998910        0.081373      0.874089     0.213942
# 3             3         0.056556        0.228486      0.037338     0.197110
# 4             4         0.991933        0.055186      0.878801     0.141952
# 5             5         1.013172        0.120977      0.899970     0.227107
# 6             6         1.005036        0.043826      0.876281     0.368792
# 7             7         0.524944        0.487066      0.457632     0.451064
# 8             8         1.005002        0.098137      0.911330     0.215324
# 9             9         0.989013        0.063665      0.894442     0.167199
# 10           10         0.981250        0.117216      0.889399     0.195568
# ...
