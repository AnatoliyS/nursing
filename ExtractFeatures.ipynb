# %%
# %load_ext autoreload
# %autoreload 2

# %%
import ioutils as io
import feature_extractor
from record import NurseSensorsRecord

full_file_paths = io.get_filepaths("./data/Labelled/sensors")

x = NurseSensorsRecord(full_file_paths[0])
features = feature_extractor.ExtractFeatures(x)
print(features)
x.frame[:10]
# Out:
# Nurse sensors record created
# {'waist_y_mean': 0.09483225589225588, 'right_y_mean': -0.08627946127946128, 'waist_norm_mean': 1.019915881559077, 'chest_norm_mean': 0.9634132369067484, 'chest_norm_std': 0.1787090523395824, 'waist_norm_std': 0.11566967910788738, 'record_length': 2079, 'waist_z_std': 0.24330323625730377, 'right_x_mean': 0.006283068783068783, 'waist_x_mean': 0.020991156806156805, 'right_z_std': 0.15424007871409334, 'chest_z_std': 0.19419038250926426, 'waist_x_std': 0.15783937118118488, 'chest_z_mean': -0.9354599711399714, 'right_x_std': 0.10906187491366055, 'right_z_mean': 0.9586790524290524, 'chest_y_mean': 0.006285478595478586, 'waist_z_mean': 0.9649561616161763, 'right_norm_std': 0.09345339925821648, 'waist_y_std': 0.1702114149771043, 'right_norm_mean': 0.9860478704463637, 'chest_y_std': 0.1738007921900246, 'right_y_std': 0.1371579760657711}
#     time  chest_x  chest_y  chest_z   waist_x   waist_y   waist_z  right_x  \
# 0  0.148  0.06018 -0.51788 -0.81879  0.031250  0.093750  0.984375  0.00000
# 1  0.148  0.06018 -0.51788 -0.81879  0.015625  0.093750  0.984375  0.00000
# 2  0.217  0.06657 -0.52687 -0.77965  0.000000  0.109375  1.015630  0.00000
# 3  0.267  0.06950 -0.53827 -0.79146  0.000000  0.109375  1.000000  0.00000
# 4  0.315  0.08992 -0.53117 -0.77147  0.000000  0.062500  1.000000  0.00000
# 5  0.372  0.10872 -0.53523 -0.80048  0.062500  0.093750  0.968750  0.00000
# 6  0.418  0.11324 -0.54033 -0.76529  0.015625  0.109375  0.984375  0.00000
# 7  0.470  0.11424 -0.54601 -0.77507  0.031250  0.109375  0.984375  0.00000
# 8  0.520  0.10533 -0.55113 -0.76846 -0.015625  0.109375  1.015630 -0.03125
# 9  0.571  0.06064 -0.51848 -0.76407 -0.093750  0.093750  0.828125  0.00000
#
#    right_y  right_z
# 0 -0.03125  1.00000
# 1 -0.03125  1.00000
# 2 -0.03125  0.96875
# 3 -0.03125  0.96875
# 4 -0.03125  1.00000
# 5 -0.03125  1.00000
# 6 -0.03125  0.96875
# 7 -0.03125  1.00000
# 8 -0.03125  1.00000
# 9 -0.06250  1.00000
